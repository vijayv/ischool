# %% [markdown]
# ## Instructions

# %% [markdown]
# https://docs.google.com/document/d/1pEVR4fFqT8nb0NMPu_vplNSAjVYBgWUKGVJzyhHZaS4/edit <br/>
# #### Feature Description
# http://lib.stat.cmu.edu/S/Harrell/data/descriptions/titanic3info.txt<br/>

# %% [markdown]
# ## Useful Examples

# %% [markdown]
# https://datastudentblog.wordpress.com/2014/03/31/titanic-how-we-got-to-12-on-the-kaggle-com-leaderboard/<br/>
# http://nbviewer.ipython.org/github/agconti/kaggle-titanic/blob/master/Titanic.ipynb <br/>
# http://www.markhneedham.com/blog/2013/11/09/python-making-scikit-learn-and-pandas-play-nice/ <br/>
# http://nbviewer.ipython.org/github/datapress/kaggle-titanic/blob/master/notebooks/Section%202-2%20-%20SVM%20with%20Parameter%20Tuning.ipynb<br/>
# http://fastml.com/converting-categorical-data-into-numbers-with-pandas-and-scikit-learn/<br/>
# #### Cross Validation
# https://randomforests.wordpress.com/2014/02/02/basics-of-k-fold-cross-validation-and-gridsearchcv-in-scikit-learn/

# %%
import numpy as np
import pandas as pd
import sklearn as sk
from math import sqrt
from sklearn.preprocessing import Imputer
from sklearn.feature_extraction import DictVectorizer
from sklearn import svm, cross_validation, grid_search
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier 
import matplotlib as plt
import string
from scipy.stats import mode, zscore
# %matplotlib inline

# %% [markdown]
# ## Hack: Yes or No?

# %%
# hack = True
hack = False

# %% [markdown]
# ## Read in Data

# %%
home_dir = ""
if hack:
    home_dir = "hack/"

training_data = pd.read_csv(home_dir + "train.csv")
training_data.columns = map(string.lower, training_data.columns)
training_data["set_type"] = "training"

testing_data = pd.read_csv(home_dir + "test.csv")
testing_data.columns = map(string.lower, testing_data.columns)
testing_data["set_type"] = "testing"

if hack:
    training_data = training_data.rename(columns = {'passengerid':'passenger_id'})
    testing_data = testing_data.rename(columns = {'passengerid':'passenger_id'}) 

all_data = pd.concat([training_data, testing_data])

# %%
all_data.head()
# Out:
#    age cabin embarked      fare             home.dest  \
# 0   39   C85        C   71.2833          New York, NY
# 1   39   NaN        S  211.3375                   NaN
# 2   36   NaN        S    7.4958  Bulgaria Chicago, IL
# 3  NaN   NaN        S    8.0500                   NaN
# 4   20   NaN        C   15.7417                   NaN
#
#                         name  parch  passenger_id  pclass  set_type     sex  \
# 0  Cumings, Mr. John Bradley      0             0       1  training    male
# 1     Kreuchen, Miss. Emilie      0             1       1  training  female
# 2           Coleff, Mr. Peju      0             2       3  training    male
# 3         Spector, Mr. Woolf      0             3       3  training    male
# 4           Nakid, Mr. Sahid      1             4       3  training    male
#
#    sibsp  survived     ticket
# 0      1         0   PC 17599
# 1      0         1      24160
# 2      0         0     349210
# 3      0         0  A.5. 3236
# 4      1         1       2653

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 523
# Data columns (total 14 columns):
# age             1046 non-null float64
# cabin           295 non-null object
# embarked        1307 non-null object
# fare            1308 non-null float64
# home.dest       745 non-null object
# name            1309 non-null object
# parch           1309 non-null int64
# passenger_id    1309 non-null int64
# pclass          1309 non-null int64
# set_type        1309 non-null object
# sex             1309 non-null object
# sibsp           1309 non-null int64
# survived        785 non-null float64
# ticket          1309 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 153.4+ KB

# %%
all_data.describe()
# Out:
#                age         fare        parch  passenger_id       pclass  \
# count  1046.000000  1308.000000  1309.000000   1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027    654.000000     2.294882
# std      14.413493    51.758668     0.865560    378.020061     0.837836
# min       0.170000     0.000000     0.000000      0.000000     1.000000
# 25%      21.000000     7.895800     0.000000    327.000000     2.000000
# 50%      28.000000    14.454200     0.000000    654.000000     3.000000
# 75%      39.000000    31.275000     0.000000    981.000000     3.000000
# max      80.000000   512.329200     9.000000   1308.000000     3.000000
#
#              sibsp    survived
# count  1309.000000  785.000000
# mean      0.498854    0.375796
# std       1.041658    0.484637
# min       0.000000    0.000000
# 25%       0.000000    0.000000
# 50%       0.000000    0.000000
# 75%       1.000000    1.000000
# max       8.000000    1.000000

# %% [markdown]
# #### We have no null values

# %%
all_data[all_data["set_type"] == "training"]["survived"].sum()
# Out:
# 295.0

# %% [markdown]
# ## Handling Missing Values

# %%
# Might be too extreme
# Remove features that have lots of missing values
# all_data = all_data.drop(['ticket','cabin'], axis=1)
# Remove NaN values
# all_data = all_data.dropna()

# %%
# age_mean = all_data['age'].mean()
# all_data['age'] = all_data['age'].fillna(age_mean)
# print all_data[all_data['age'].isnull()]

# mode_embarked = mode(all_data['embarked'])[0][0]
# all_data['embarked'] = all_data['embarked'].fillna(mode_embarked)
for c in range(1,4):
    # Fare
    mask = (all_data['fare'].isnull()) & (all_data['pclass'] == c)
    all_data['fare'][mask] = all_data['fare'][all_data['pclass'] == c].mean()
    
    # Age
    mask = (all_data['age'].isnull()) & (all_data['pclass'] == c)
    all_data['age'][mask] = all_data['age'][all_data['pclass'] == c].mean()
    # Embarked
    mask = (all_data['embarked'].isnull()) & (all_data['pclass'] == c)
    all_data['embarked'][mask] = mode(all_data['embarked'][all_data['pclass'] == c])[0][0]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 523
# Data columns (total 14 columns):
# age             1309 non-null float64
# cabin           295 non-null object
# embarked        1309 non-null object
# fare            1309 non-null float64
# home.dest       745 non-null object
# name            1309 non-null object
# parch           1309 non-null int64
# passenger_id    1309 non-null int64
# pclass          1309 non-null int64
# set_type        1309 non-null object
# sex             1309 non-null object
# sibsp           1309 non-null int64
# survived        785 non-null float64
# ticket          1309 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 153.4+ KB

# %% [markdown]
# ## Feature Construction

# %% [markdown]
# #### Nationality

# %%
us = ['WA', 'WI', 'WV', 'FL', 'WY', 'NH', 'NJ', 'NM', 'NA', 'NC', 'ND', 'NE', 'NY', 'RI', 'NV', 'GU', 'CO', 'CA', 'GA', 'CT', 'OK', 'OH', 'KS', 'SC', 'KY', 'OR', 'SD', 'DE', 'DC', 'HI', 'PR', 'TX', 'LA', 'TN', 'PA', 'VA', 'VI', 'AK', 'AL', 'AS', 'AR', 'VT', 'IL', 'IN', 'IA', 'AZ', 'ID', 'ME', 'MD', 'MA', 'UT', 'MO', 'MN', 'MI', 'MT', 'MP', 'MS']
ca = ['ON', 'AB', 'NL', 'BC', 'NB', 'MB', 'YT', 'SK', 'QC', 'PE', 'NS', 'NT', 'NU']

# %%
def is_state(test_list):
    if type(test_list) == list:
        if np.array([t.strip() in us for t in test_list.split(",")]).any():
            return "US"
        if np.array([t.strip() in ca for t in test_list.split(",")]).any():
            return "CA"
    else:
        return "Unknown"
if not hack:
    all_data["ending_in_na"] = all_data["home.dest"].apply(is_state)

# %% [markdown]
# #### Binary Gender Class

# %%
all_data["female_high_class"] = (all_data['sex'] == "female") & (all_data['pclass'] == 1)

# %% [markdown]
# #### Title

# %%
all_data["title"] = ""
all_data["title"][all_data["name"].str.contains('Sir[\. ]|Capt[\. ]|Col[\. ]|Don[\. ]|Dr[\. ]|Jonkheer[\. ]|Major[\. ]|Rev[\. ]|Sir[\. ]')] = "noble"
all_data["title"][all_data["name"].str.contains('Mme[\. ]|Mlle[\. ]')] = "mlle"
all_data["title"][all_data["name"].str.contains('Dona[\. ]|Countess[\. ]|Lady[\. ]')] = "lady"

# %% [markdown]
# #### Has Title

# %%
all_data["has_title"] = all_data["title"] != ""

# %% [markdown]
# #### Family Size

# %%
all_data["family_size"] = all_data.sibsp + all_data.parch + 1

# %% [markdown]
# #### Travelling Alone?

# %%
all_data["travelling_alone"] = all_data["family_size"] <= 1

# %% [markdown]
# #### Place on Ship

# %%
all_data["side"] = "unknown"
all_data["cabin_last_digit"] = all_data.cabin.apply(lambda x: int(0 if str(x)[-1:] in string.letters else str(x)[-1:]))
all_data["side"][all_data["cabin_last_digit"] % 2 == 0] = "port"
all_data["side"][all_data["cabin_last_digit"] % 2 != 0] = "starboard"
all_data["side"][all_data["cabin_last_digit"] == 0] = "unknown"
all_data.drop("cabin_last_digit", axis=1, inplace=True)

# %% [markdown]
# #### Classifying Fares

# %%
all_data["fare_bin"] = "<10"
all_data["fare_bin"][all_data["fare"] >= 10] = "10-20"
all_data["fare_bin"][all_data["fare"] >= 20] = "20-30"
all_data["fare_bin"][all_data["fare"] >= 30] = "30+"

# %% [markdown]
# #### Passenger Name Length

# %%
all_data["name_length"] = all_data["name"].apply(len)

# %% [markdown]
# #### Adding Variables Names

# %%
all_data["has_cabin_info"] = all_data["cabin"].apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# #### zscore age

# %%
mean_age = all_data["age"].mean()
stdev_age = np.std(all_data["age"])
all_data["z_age"] = map(lambda x: (x - mean_age) / stdev_age, all_data["age"])
all_data["z_age"].count()
# Out:
# 1309

# %% [markdown]
# #### age bin

# %%
all_data["age_bin"] = "<18"
all_data["age_bin"][all_data["age"] >= 16] = "18-50"
all_data["age_bin"][all_data["age"] >= 50] = "50+"

# %%
all_data
# Out:
#            age            cabin embarked      fare  \
# 0    39.000000              C85        C   71.2833
# 1    39.000000              NaN        S  211.3375
# 2    36.000000              NaN        S    7.4958
# 3    24.816367              NaN        S    8.0500
# 4    20.000000              NaN        C   15.7417
# 5    21.000000  B57 B59 B63 B66        C  262.3750
# 6    16.000000              NaN        S    7.6500
# 7    24.816367              NaN        Q   15.5000
# 8    42.000000              NaN        S   32.5000
# 9    31.000000          E39 E41        C  134.5000
# 10   29.506705              NaN        C   15.5792
# 11   24.816367              NaN        S    8.0500
# 12   50.000000              NaN        S   26.0000
# 13   24.816367              NaN        C   15.2458
# 14   20.000000              NaN        S    7.0500
# 15   24.000000              NaN        S   31.5000
# 16   31.000000              B20        S   57.0000
# 17   47.000000             C110        S   52.0000
# 18   22.000000              NaN        C    7.2292
# 19   67.000000          C55 C57        S  221.7792
# 20   34.000000              NaN        S   26.0000
# 21   30.000000              NaN        S   10.5000
# 22   23.000000              NaN        S   10.5000
# 23   23.000000              NaN        S    7.8542
# 24   22.000000              NaN        S   10.5000
# 25   17.000000              NaN        S   73.5000
# 26   24.816367              NaN        S    8.0500
# 27   28.000000              NaN        S    7.8958
# 28   55.000000              NaN        C   27.7208
# 29   33.000000      B51 B53 B55        S    5.0000
# ..         ...              ...      ...       ...
# 494  24.000000              NaN        S    7.8542
# 495  51.000000              D28        S   39.4000
# 496  23.000000              NaN        S   11.5000
# 497  22.000000              NaN        S    7.2500
# 498  47.000000              E31        S   61.1750
# 499  21.000000              NaN        S    7.8542
# 500  24.816367              NaN        C   22.3583
# 501  25.000000              E50        C   55.4417
# 502  18.000000              NaN        S    8.6625
# 503  40.500000              NaN        S   14.5000
# 504  74.000000              NaN        S    7.7750
# 505  31.000000              NaN        Q    7.7500
# 506  19.000000      C23 C25 C27        S  263.0000
# 507  29.000000              NaN        S   21.0000
# 508  24.816367              NaN        S   14.5000
# 509  33.000000               E8        S   53.1000
# 510   3.000000              NaN        S   21.0750
# 511  63.000000              NaN        S   26.0000
# 512  21.000000              NaN        S    7.9250
# 513  48.000000              A16        C   39.6000
# 514  24.816367              NaN        Q    7.7500
# 515  44.000000              NaN        S   13.0000
# 516  24.000000              NaN        S   27.0000
# 517  24.816367              NaN        S   69.5500
# 518  20.000000              NaN        S    7.8542
# 519  45.000000              NaN        S  164.8667
# 520  26.500000              NaN        C    7.2250
# 521  53.000000              NaN        C   27.4458
# 522  21.000000              NaN        S   26.5500
# 523  30.500000              NaN        S    8.0500
#
#                                 home.dest  \
# 0                            New York, NY
# 1                                     NaN
# 2                    Bulgaria Chicago, IL
# 3                                     NaN
# 4                                     NaN
# 5         Haverford, PA / Cooperstown, NY
# 6                  Norway Los Angeles, CA
# 7                                     NaN
# 8                           Greenport, NY
# 9                                     NaN
# 10                           New York, NY
# 11                                    NaN
# 12                    Woodford County, KY
# 13                         Syria Kent, ON
# 14                               Portugal
# 15               Guernsey / Elizabeth, NJ
# 16                            Calgary, AB
# 17                          Worcester, MA
# 18                                    NaN
# 19                           New York, NY
# 20                       Warwick, England
# 21                   Walthamstow, England
# 22                                    NaN
# 23       Krakoryd, Sweden Bloomington, IL
# 24   Pondersend, England / New Durham, NJ
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                      Stockholm, Sweden
# 29                           New York, NY
# ..                                    ...
# 494          Goteborg, Sweden Huntley, IL
# 495                         Paris, France
# 496                  Cornwall / Akron, OH
# 497                                   NaN
# 498                            Amenia, ND
# 499                                   NaN
# 500                                   NaN
# 501                          Brooklyn, NY
# 502                                   NaN
# 503                                   NaN
# 504                                   NaN
# 505                  Ireland Brooklyn, NY
# 506                          Winnipeg, MB
# 507                     Plymouth, England
# 508                                   NaN
# 509             New York, NY / Ithaca, NY
# 510                                   NaN
# 511                      Swindon, England
# 512                                   NaN
# 513                        London / Paris
# 514                                   NaN
# 515              Seattle, WA / Toledo, OH
# 516                                London
# 517                                   NaN
# 518                    Sweden Chicago, IL
# 519                        Youngstown, OH
# 520                                   NaN
# 521                        Washington, DC
# 522                            Duluth, MN
# 523                                   NaN
#
#                                                   name  parch  passenger_id  \
# 0                            Cumings, Mr. John Bradley      0             0
# 1                               Kreuchen, Miss. Emilie      0             1
# 2                                     Coleff, Mr. Peju      0             2
# 3                                   Spector, Mr. Woolf      0             3
# 4                                     Nakid, Mr. Sahid      1             4
# 5                Ryerson, Miss. Susan Parker "Suzette"      2             5
# 6                          Abelseth, Miss. Karen Marie      0             6
# 7                       Murphy, Miss. Katherine "Kate"      0             7
# 8                               Drew, Mr. James Vivian      1             8
# 9                            Wilson, Miss. Helen Alice      0             9
# 10                   Mangiavacchi, Mr. Serafino Emilio      0            10
# 11                                 Ware, Mr. Frederick      0            11
# 12                         Parrish, Mrs. (Lutie Davis)      1            12
# 13                       Boulos, Mrs. Joseph (Sultana)      2            13
# 14                      Coelho, Mr. Domingos Fernandeo      0            14
# 15                       Jefferys, Mr. Clifford Thomas      0            15
# 16                             Dick, Mr. Albert Adrian      0            16
# 17                      Porter, Mr. Walter Chamberlain      0            17
# 18                               Sirayanian, Mr. Orsen      0            18
# 19                                  Straus, Mr. Isidor      0            19
# 20                                Angle, Mr. William A      0            20
# 21                                  Harris, Mr. Walter      0            21
# 22                           Ware, Mr. William Jeffery      0            22
# 23                              Augustsson, Mr. Albert      0            23
# 24                           Oxenham, Mr. Percy Thomas      0            24
# 25                           Deacon, Mr. Percy William      0            25
# 26                                 Murdlin, Mr. Joseph      0            26
# 27                             Petranec, Miss. Matilda      0            27
# 28           Lindstrom, Mrs. Carl Johan (Sigrid Posse)      0            28
# 29                            Carlsson, Mr. Frans Olof      0            29
# ..                                                 ...    ...           ...
# 494                          Carlsson, Mr. Carl Robert      0          1279
# 495     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1          1280
# 496                        Hocking, Mr. Richard George      1          1281
# 497                                 Dennis, Mr. Samuel      0          1282
# 498  Chaffee, Mrs. Herbert Fuller (Carrie Constance...      0          1283
# 499                      Nilsson, Mr. August Ferdinand      0          1284
# 500                           Peter, Master. Michael J      1          1285
# 501                        Harder, Mr. George Achilles      0          1286
# 502                               Cacic, Mr. Jego Grga      0          1287
# 503                    van Billiard, Mr. Austin Blyler      2          1288
# 504                                Svensson, Mr. Johan      0          1289
# 505                            Connaghton, Mr. Michael      0          1290
# 506                     Fortune, Mr. Charles Alexander      2          1291
# 507                    Turpin, Mr. William John Robert      0          1292
# 508                                 Garfirth, Mr. John      0          1293
# 509     Chambers, Mrs. Norman Campbell (Bertha Griggs)      0          1294
# 510                         Palsson, Miss. Stina Viola      1          1295
# 511                               Howard, Mr. Benjamin      0          1296
# 512                              Pekoniemi, Mr. Edvard      0          1297
# 513  Duff Gordon, Lady. (Lucille Christiana Sutherl...      0          1298
# 514                            O'Donoghue, Ms. Bridget      0          1299
# 515                             Harbeck, Mr. William H      0          1300
# 516  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...      1          1301
# 517                     Sage, Mrs. John (Annie Bullen)      9          1302
# 518                         Andreasson, Mr. Paul Edvin      0          1303
# 519         Wick, Mrs. George Dennick (Mary Hitchcock)      1          1304
# 520                          Zakarian, Mr. Mapriededer      0          1305
# 521   Candee, Mrs. Edward (Helen Churchill Hungerford)      0          1306
# 522                           Willard, Miss. Constance      0          1307
# 523                         Tomlin, Mr. Ernest Portage      0          1308
#
#      pclass  set_type   ...   title  has_title  family_size travelling_alone  \
# 0         1  training   ...              False            2            False
# 1         1  training   ...              False            1             True
# 2         3  training   ...              False            1             True
# 3         3  training   ...              False            1             True
# 4         3  training   ...              False            3            False
# 5         1  training   ...              False            5            False
# 6         3  training   ...              False            1             True
# 7         3  training   ...              False            2            False
# 8         2  training   ...              False            3            False
# 9         1  training   ...              False            1             True
# 10        2  training   ...              False            1             True
# 11        3  training   ...              False            1             True
# 12        2  training   ...              False            2            False
# 13        3  training   ...              False            3            False
# 14        3  training   ...              False            1             True
# 15        2  training   ...              False            3            False
# 16        1  training   ...              False            2            False
# 17        1  training   ...              False            1             True
# 18        3  training   ...              False            1             True
# 19        1  training   ...              False            2            False
# 20        2  training   ...              False            2            False
# 21        2  training   ...              False            1             True
# 22        2  training   ...              False            2            False
# 23        3  training   ...              False            1             True
# 24        2  training   ...              False            1             True
# 25        2  training   ...              False            1             True
# 26        3  training   ...              False            1             True
# 27        3  training   ...              False            1             True
# 28        1  training   ...              False            1             True
# 29        1  training   ...              False            1             True
# ..      ...       ...   ...     ...        ...          ...              ...
# 494       3   testing   ...              False            1             True
# 495       1   testing   ...              False            2            False
# 496       2   testing   ...              False            4            False
# 497       3   testing   ...              False            1             True
# 498       1   testing   ...              False            2            False
# 499       3   testing   ...              False            1             True
# 500       3   testing   ...              False            3            False
# 501       1   testing   ...              False            2            False
# 502       3   testing   ...              False            1             True
# 503       3   testing   ...              False            3            False
# 504       3   testing   ...              False            1             True
# 505       3   testing   ...              False            1             True
# 506       1   testing   ...              False            6            False
# 507       2   testing   ...              False            2            False
# 508       3   testing   ...              False            1             True
# 509       1   testing   ...              False            2            False
# 510       3   testing   ...              False            5            False
# 511       2   testing   ...              False            2            False
# 512       3   testing   ...              False            1             True
# 513       1   testing   ...    lady       True            2            False
# 514       3   testing   ...              False            1             True
# 515       2   testing   ...              False            1             True
# 516       2   testing   ...              False            4            False
# 517       3   testing   ...              False           11            False
# 518       3   testing   ...              False            1             True
# 519       1   testing   ...              False            3            False
# 520       3   testing   ...              False            1             True
# 521       1   testing   ...              False            1             True
# 522       1   testing   ...              False            1             True
# 523       3   testing   ...              False            1             True
#
#           side fare_bin name_length has_cabin_info     z_age age_bin
# 0    starboard      30+          25              1  0.735495   18-50
# 1      unknown      30+          22              0  0.735495   18-50
# 2      unknown      <10          16              0  0.506886   18-50
# 3      unknown      <10          18              0 -0.345341   18-50
# 4      unknown    10-20          16              0 -0.712363   18-50
# 5         port      30+          37              1 -0.636160   18-50
# 6      unknown      <10          27              0 -1.017175   18-50
# 7      unknown    10-20          30              0 -0.345341   18-50
# 8      unknown      30+          22              0  0.964104   18-50
# 9    starboard      30+          25              1  0.125871   18-50
# 10     unknown    10-20          33              0  0.012077   18-50
# 11     unknown      <10          19              0 -0.345341   18-50
# 12     unknown    20-30          27              0  1.573729     50+
# 13     unknown    10-20          29              0 -0.345341   18-50
# 14     unknown      <10          30              0 -0.712363   18-50
# 15     unknown      30+          29              0 -0.407551   18-50
# 16     unknown      30+          23              1  0.125871   18-50
# 17     unknown      30+          30              1  1.345120   18-50
# 18     unknown      <10          21              0 -0.559957   18-50
# 19   starboard      30+          18              1  2.869180     50+
# 20     unknown    20-30          20              0  0.354480   18-50
# 21     unknown    10-20          18              0  0.049668   18-50
# 22     unknown    10-20          25              0 -0.483754   18-50
# 23     unknown      <10          22              0 -0.483754   18-50
# 24     unknown    10-20          25              0 -0.559957   18-50
# 25     unknown      30+          25              0 -0.940972   18-50
# 26     unknown      <10          19              0 -0.345341   18-50
# 27     unknown      <10          23              0 -0.102738   18-50
# 28     unknown    20-30          41              0  1.954744     50+
# 29   starboard      <10          24              1  0.278277   18-50
# ..         ...      ...         ...            ...       ...     ...
# 494    unknown      <10          25              0 -0.407551   18-50
# 495       port      30+          46              1  1.649932     50+
# 496    unknown    10-20          27              0 -0.483754   18-50
# 497    unknown      <10          18              0 -0.559957   18-50
# 498  starboard      30+          55              1  1.345120   18-50
# 499    unknown      <10          29              0 -0.636160   18-50
# 500    unknown    20-30          24              0 -0.345341   18-50
# 501    unknown      30+          27              1 -0.331348   18-50
# 502    unknown      <10          20              0 -0.864769   18-50
# 503    unknown    10-20          31              0  0.849800   18-50
# 504    unknown      <10          19              0  3.402602     50+
# 505    unknown      <10          23              0  0.125871   18-50
# 506  starboard      30+          30              1 -0.788566   18-50
# 507    unknown    20-30          31              0 -0.026535   18-50
# 508    unknown    10-20          18              0 -0.345341   18-50
# 509       port      30+          46              1  0.278277   18-50
# 510    unknown    20-30          26              0 -2.007815     <18
# 511    unknown    20-30          20              0  2.564368     50+
# 512    unknown      <10          21              0 -0.636160   18-50
# 513       port      30+          65              1  1.421323   18-50
# 514    unknown      <10          23              0 -0.345341   18-50
# 515    unknown    10-20          22              0  1.116510   18-50
# 516    unknown    20-30          51              0 -0.407551   18-50
# 517    unknown      30+          30              0 -0.345341   18-50
# 518    unknown      <10          26              0 -0.712363   18-50
# 519    unknown      30+          42              0  1.192713   18-50
# 520    unknown      <10          25              0 -0.217043   18-50
# 521    unknown    20-30          48              0  1.802338     50+
# 522    unknown    20-30          24              0 -0.636160   18-50
# 523    unknown      <10          26              0  0.087769   18-50
#
# [1309 rows x 26 columns]

# %% [markdown]
# ## Transform Variables

# %%
all_data.dtypes
# Out:
# age                  float64
# cabin                 object
# embarked              object
# fare                 float64
# home.dest             object
# name                  object
# parch                  int64
# passenger_id           int64
# pclass                 int64
# set_type              object
# sex                   object
# sibsp                  int64
# survived             float64
# ticket                object
# ending_in_na          object
# female_high_class       bool
# title                 object
# has_title               bool
# family_size            int64
# travelling_alone        bool
# side                  object
# fare_bin              object
# name_length            int64
# has_cabin_info         int64
# z_age                float64
# age_bin               object
# dtype: object

# %%
training_data = all_data[all_data["set_type"] == "training"]
testing_data = all_data[all_data["set_type"] == "testing"]
Y = training_data["survived"]

# %% [markdown]
# ## Set Features

# %%
numeric_features = [col for col in all_data.columns if all_data[col].dtype in [float, int] and col != "survived"]
categorical_features = [col for col in all_data.columns if all_data[col].dtype in [object]]
numeric_features = ["pclass", "family_size", "female_high_class", "travelling_alone"]
categorical_features = ["sex", "fare_bin", "embarked", "age_bin"]

X_train_num = training_data[numeric_features].as_matrix()
X_test_num = testing_data[numeric_features].as_matrix()

training_data[categorical_features].fillna('NA', inplace=True)
testing_data[categorical_features].fillna('NA', inplace=True)

v = DictVectorizer(sparse = False).fit(all_data[categorical_features].T.to_dict().values())
X_train_cat = v.transform(training_data[categorical_features].T.to_dict().values())
X_test_cat = v.transform(testing_data[categorical_features].T.to_dict().values())

# Combine Numeric and Categorical

X_train = np.hstack(( X_train_num, X_train_cat ))
X_test = np.hstack(( X_test_num, X_test_cat ))

print X_train.shape, X_train_num.shape, X_train_cat.shape
print X_test.shape, X_test_num.shape, X_test_cat.shape
# Out:
# (785, 16) (785, 4) (785, 12)
# (524, 16) (524, 4) (524, 12)

# %% [markdown]
# ### SVM Model

# %% [markdown]
# #### Train the model

# %%
# kf_total = cross_validation.KFold(len(X_train), n_folds=5, shuffle=True, random_state=4)
clf = svm.SVC()
# clf = svm.LinearSVC()
# clf = svm.SVC(kernel='poly', gamma=3) 
parameter_grid = {
    'kernel' : ['rbf'],
    'gamma': [0.0,0.1,0.01],
    'C': [1., 10., 100.]
}
clfgs = grid_search.GridSearchCV(estimator=clf, param_grid=parameter_grid, n_jobs=1, cv=5) # , verbose=3
clfgs.fit(X_train, Y)
print clfgs.best_estimator_
print clfgs.best_score_
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.1,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)
# 0.829299363057

# %% [markdown]
# #### Predict on the training set

# %%
train_predictions = clfgs.predict(X_train)
train_predictions = zip(training_data["passenger_id"], train_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
train_predictions = pd.DataFrame(train_predictions, columns=output_columns)
print train_predictions.sum()
print len(train_predictions)
# Out:
# passenger_id    307720
# survived           256
# dtype: int64
# 785

# %%
train_predictions.to_csv(home_dir + "train_rbfsvm_c10_g01.csv", index=False)

# %% [markdown]
# #### Predict on the test set

# %%
test_predictions = clfgs.predict(X_test)
final_predictions = zip(testing_data["passenger_id"],test_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
final_predictions = pd.DataFrame(final_predictions, columns=output_columns)
print final_predictions.sum()
print len(final_predictions)
# Out:
# passenger_id    548366
# survived           207
# dtype: int64
# 524

# %%
final_predictions.to_csv(home_dir + "9_rbfsvm_c100_g01.csv", index=False)

# %% [markdown]
# # Everything Below is Experimentation

# %% [markdown]
# ## Random Forests

# %% [markdown]
# #### http://scikit-learn.org/stable/modules/ensemble.html#parameters

# %%
# Create the random forest object which will include all the parameters
# for the fit
n_features = len(categorical_features) + len(numeric_features)
forest = RandomForestClassifier(n_estimators = 1000, max_features=int(round(sqrt(n_features))), max_depth=None, min_samples_split=1)

scores = sk.cross_validation.cross_val_score(forest, X_train, Y)
print scores.mean()
# Out:
# 0.793569628367

# %%
# Fit the training data to the Survived labels and create the decision trees
forest = forest.fit(X_train,Y)

# Take the same decision trees and run it on the test data
test_predictions = forest.predict(X_test)

# %%
final_predictions = zip(testing_data["passenger_id"],test_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
final_predictions = pd.DataFrame(final_predictions, columns=output_columns)
print final_predictions.sum()
print len(final_predictions)
# Out:
# passenger_id    548366
# survived           193
# dtype: int64
# 524

# %%
final_predictions.to_csv(home_dir + "7_random_forest.csv", index=False)

# %%
train_predictions = forest.predict(X_train)
train_predictions = zip(training_data["passenger_id"], train_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
train_predictions = pd.DataFrame(train_predictions, columns=output_columns)
print train_predictions.sum()
print len(train_predictions)
# Out:
# passenger_id    307720
# survived           249
# dtype: int64
# 785

# %%
train_predictions.to_csv(home_dir + "train_random_forest.csv", index=False)

# %% [markdown]
# ## Adaboost

# %%
clf = AdaBoostClassifier(n_estimators=100)

# Fit the training data to the Survived labels and create the decision trees
clf = clf.fit(X_train,Y)

# Take the same decision trees and run it on the test data
test_predictions = clf.predict(X_test)

scores = sk.cross_validation.cross_val_score(clf, X_train, Y)
scores.mean()
# Out:
# 0.80376731786198163

# %%
final_predictions = zip(testing_data["passenger_id"], test_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
final_predictions = pd.DataFrame(final_predictions, columns=output_columns)
print final_predictions.sum()
print len(final_predictions)
# Out:
# passenger_id    548366
# survived           210
# dtype: int64
# 524

# %%
final_predictions.to_csv(home_dir + "1_adaboost.csv", index=False)

# %%
train_predictions = clf.predict(X_train)
train_predictions = zip(training_data["passenger_id"], train_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
train_predictions = pd.DataFrame(train_predictions, columns=output_columns)
print train_predictions.sum()
print len(train_predictions)
# Out:
# passenger_id    307720
# survived           251
# dtype: int64
# 785

# %%
train_predictions.to_csv(home_dir + "train_1_adaboost.csv", index=False)

# %% [markdown]
# ## Decision Trees

# %%
dt = DecisionTreeClassifier()
dt = dt.fit(X_train, Y)
test_predictions = dt.predict(X_test)

# %%
final_predictions = zip(testing_data["passenger_id"],test_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
final_predictions = pd.DataFrame(final_predictions, columns=output_columns)
print final_predictions.sum()
print len(final_predictions)
# Out:
# passenger_id    548366
# survived           193
# dtype: int64
# 524

# %%
final_predictions.to_csv(home_dir + "2_decision_tree.csv", index=False)

# %%
train_predictions = dt.predict(X_train)
train_predictions = zip(training_data["passenger_id"], train_predictions.astype(int))
output_columns = "passenger_id", "survived"
if hack:
    output_columns = "PassengerId", "Survived"
train_predictions = pd.DataFrame(train_predictions, columns=output_columns)
print train_predictions.sum()
print len(train_predictions)
# Out:
# passenger_id    307720
# survived           243
# dtype: int64
# 785

# %%
train_predictions.to_csv(home_dir + "train_2_decisiontree.csv", index=False)

# %% [markdown]
# ## Archive

# %%
cross_validation.cross_val_score(clfgs, categorical_training_data, training_data["survived"], cv=kf_total, n_jobs = 1)
